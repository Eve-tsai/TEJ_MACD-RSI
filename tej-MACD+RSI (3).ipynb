# %% [markdown]
# # 設定基本套件與環境變數

# %% [markdown]
# ##### anaconda prompt
# ######  (base) C:\Users\sunny>conda activate zipline-tej
# ######  (zipline-tej) C:\Users\sunny>pip install TA_Lib-0.4.29-cp311-cp311-win_amd64.whl
# ######  (zipline-tej) C:\Users\sunny>jupyter notebook

# %%
import os    
import pandas as pd
import numpy as np
import copy
import matplotlib.pyplot as plt
import talib

tej_key = 'Qgn5it5vHNpA69JeLAtE5MoUOdZ7xT'
api_base = 'https://api.tej.com.tw'

os.environ['TEJAPI_BASE'] = api_base
os.environ['TEJAPI_KEY'] = tej_key

# %% [markdown]
# # 使用 get_universe() 函式取得股票池
# ##### ->股票池範圍
# ##### (1)主產業別: 電子工業
# ##### (2)證券種類: 普通股
# ##### (3)板塊別: 上市一般版

# %%
from zipline.sources.TEJ_Api_Data import get_universe

#2022-06-01 2023-06-01
pool = get_universe(start = '2022-06-01', 
                    end = '2023-06-01', 
                    main_ind_c = 'M2300 電子工業',
                    stktp_e= 'Common Stock', 
                    mkt_bd_e=['TSE']) 
pool
# Out:
# Currently used TEJ API key call quota 544/1000 (54.4%)
# Currently used TEJ API key data quota 3885348/10000000 (38.85%)
# ['1471',
#  '1582',
#  '2059',
#  '2301',
#  '2302',
#  '2303',
#  '2305',
#  '2308',
#  '2312',
#  '2313',
#  '2314',
#  '2316',
#  '2317',
#  '2321',
#  '2323',
#  '2324',
#  '2327',
#  '2328',
#  '2329',
#  '2330',
#  '2331',
#  '2332',
#  '2337',
#  '2338',
#  '2340',
#  '2342',
#  '2344',
#  '2345',
#  '2347',
#  '2349',
#  '2351',
#  '2352',
#  '2353',
#  '2354',
#  '2355',
#  '2356',
#  '2357',
#  '2359',
#  '2360',
#  '2362',
#  '2363',
#  '2364',
#  '2365',
#  '2367',
#  '2368',
#  '2369',
#  '2373',
#  '2374',
#  '2375',
#  '2376',
#  '2377',
#  '2379',
#  '2380',
#  '2382',
#  '2383',
#  '2385',
#  '2387',
#  '2388',
#  '2390',
#  '2392',
#  '2393',
#  '2395',
#  '2397',
#  '2399',
#  '2401',
#  '2402',
#  '2404',
#  '2405',
#  '2406',
#  '2408',
#  '2409',
#  '2412',
#  '2413',
#  '2414',
#  '2415',
#  '2417',
#  '2419',
#  '2420',
#  '2421',
#  '2423',
#  '2424',
#  '2425',
#  '2426',
#  '2427',
#  '2428',
#  '2429',
#  '2430',
#  '2431',
#  '2433',
#  '2434',
#  '2436',
#  '2438',
#  '2439',
#  '2440',
#  '2441',
#  '2442',
#  '2444',
#  '2449',
#  '2450',
#  '2451',
#  '2453',
#  '2454',
#  '2455',
#  '2457',
#  '2458',
#  '2459',
#  '2460',
#  '2461',
#  '2462',
#  '2464',
#  '2465',
#  '2466',
#  '2467',
#  '2468',
#  '2471',
#  '2472',
#  '2474',
#  '2476',
#  '2477',
#  '2478',
#  '2480',
#  '2481',
#  '2482',
#  '2483',
#  '2484',
#  '2485',
#  '2486',
#  '2488',
#  '2489',
#  '2491',
#  '2492',
#  '2493',
#  '2495',
#  '2498',
#  '3002',
#  '3003',
#  '3005',
#  '3006',
#  '3008',
#  '3010',
#  '3011',
#  '3013',
#  '3014',
#  '3015',
#  '3016',
#  '3017',
#  '3018',
#  '3019',
#  '3021',
#  '3022',
#  '3023',
#  '3024',
#  '3025',
#  '3026',
#  '3027',
#  '3028',
#  '3029',
#  '3030',
#  '3031',
#  '3032',
#  '3033',
#  '3034',
#  '3035',
#  '3036',
#  '3037',
#  '3038',
#  '3041',
#  '3042',
#  '3043',
#  '3044',
#  '3045',
#  '3046',
#  '3047',
#  '3048',
#  '3049',
#  '3050',
#  '3051',
#  '3054',
#  '3055',
#  '3057',
#  '3058',
#  '3059',
#  '3060',
#  '3062',
#  '3090',
#  '3092',
#  '3094',
#  '3130',
#  '3138',
#  '3149',
#  '3189',
#  '3209',
#  '3229',
#  '3231',
#  '3257',
#  '3296',
#  '3305',
#  '3308',
#  '3311',
#  '3312',
#  '3321',
#  '3338',
#  '3356',
#  '3376',
#  '3380',
#  '3383',
#  '3406',
#  '3413',
#  '3416',
#  '3419',
#  '3432',
#  '3437',
#  '3443',
#  '3447',
#  '3450',
#  '3454',
#  '3481',
#  '3494',
#  '3501',
#  '3504',
#  '3515',
#  '3518',
#  '3528',
#  '3530',
#  '3532',
#  '3533',
#  '3535',
#  '3536',
#  '3543',
#  '3545',
#  '3550',
#  '3563',
#  '3576',
#  '3583',
#  '3588',
#  '3591',
#  '3592',
#  '3593',
#  '3596',
#  '3605',
#  '3607',
#  '3617',
#  '3622',
#  '3645',
#  '3652',
#  '3653',
#  '3669',
#  '3679',
#  '3682',
#  '3686',
#  '3694',
#  '3701',
#  '3702',
#  '3704',
#  '3706',
#  '3711',
#  '3712',
#  '3714',
#  '3715',
#  '4545',
#  '4904',
#  '4906',
#  '4915',
#  '4916',
#  '4919',
#  '4934',
#  '4938',
#  '4942',
#  '4952',
#  '4956',
#  '4960',
#  '4961',
#  '4967',
#  '4968',
#  '4976',
#  '4989',
#  '4994',
#  '4999',
#  '5203',
#  '5222',
#  '5234',
#  '5244',
#  '5258',
#  '5269',
#  '5285',
#  '5388',
#  '5434',
#  '5469',
#  '5471',
#  '5484',
#  '6108',
#  '6112',
#  '6115',
#  '6116',
#  '6117',
#  '6120',
#  '6128',
#  '6133',
#  '6136',
#  '6139',
#  '6141',
#  '6142',
#  '6152',
#  '6153',
#  '6155',
#  '6164',
#  '6166',
#  '6168',
#  '6172',
#  '6176',
#  '6183',
#  '6189',
#  '6191',
#  '6192',
#  '6196',
#  '6197',
#  '6201',
#  '6202',
#  '6205',
#  '6206',
#  '6209',
#  '6213',
#  '6214',
#  '6215',
#  '6216',
#  '6224',
#  '6225',
#  '6226',
#  '6230',
#  '6235',
#  '6239',
#  '6243',
#  '6251',
#  '6257',
#  '6269',
#  '6271',
#  '6277',
#  '6278',
#  '6281',
#  '6282',
#  '6283',
#  '6285',
#  '6289',
#  '6405',
#  '6409',
#  '6412',
#  '6414',
#  '6416',
#  '6426',
#  '6438',
#  '6442',
#  '6443',
#  '6449',
#  '6477',
#  '6515',
#  '6531',
#  '6533',
#  '6552',
#  '6558',
#  '6579',
#  '6668',
#  '6669',
#  '6674',
#  '6689',
#  '6691',
#  '6695',
#  '6698',
#  '6706',
#  '6715',
#  '6719',
#  '6743',
#  '6756',
#  '6770',
#  '6776',
#  '6789',
#  '6792',
#  '6799',
#  '6830',
#  '6834',
#  '6835',
#  '8011',
#  '8016',
#  '8021',
#  '8028',
#  '8039',
#  '8046',
#  '8070',
#  '8072',
#  '8081',
#  '8101',
#  '8103',
#  '8104',
#  '8105',
#  '8110',
#  '8112',
#  '8114',
#  '8131',
#  '8150',
#  '8163',
#  '8201',
#  '8210',
#  '8213',
#  '8215',
#  '8249',
#  '8261',
#  '8271',
#  '9912']

# %%
len(pool)
# Out:
# 407

# %% [markdown]
# # 利用 TejToolAPI 抓取所需的財務資料
# ##### ->選股條件
# ##### (1)最近年度毛利率>產業平均
# ##### (2)股票交易月平均周轉率>10%

# %%
import TejToolAPI

start_time = pd.Timestamp('2022-06-01')
end_time = pd.Timestamp('2023-06-01')  # 將時間字串轉換成時間格式

data = TejToolAPI.get_history_data(start = start_time,
                                   end = end_time,
                                   ticker = pool ,  
                                   fin_type = 'A', 
                                   columns = ['營業毛利率','周轉率'],
                                   transfer_to_chinese = True)

data
# Out:
# Currently used TEJ API key call quota 577/1000 (57.7%)
# Currently used TEJ API key data quota 4172607/10000000 (41.73%)
#        股票代碼         日期     周轉率  營業毛利率_A
# 0      1471 2022-06-01  0.8503     1.22
# 1      1471 2022-06-02  2.8953     1.22
# 2      1471 2022-06-06  1.3430     1.22
# 3      1471 2022-06-07  0.8024     1.22
# 4      1471 2022-06-08  0.8270     1.22
# ...     ...        ...     ...      ...
# 97927  9912 2023-05-26  0.0706    39.30
# 97928  9912 2023-05-29  0.1557    39.30
# 97929  9912 2023-05-30  0.0272    39.30
# 97930  9912 2023-05-31  0.1195    39.30
# 97931  9912 2023-06-01  0.1648    39.30
#
# [97932 rows x 4 columns]

# %% [markdown]
# ## 1.最近年度毛利率＞產業平均值

# %%
# 取出股票基本資料與 營業毛利率資料方便觀察
data_last_1Y = data[data['日期'] == '2023-06-01'].reset_index(drop = True)  
GM_1Y_data = data_last_1Y[['股票代碼', '日期', '營業毛利率_A']]
GM_1Y_data
# Out:
#      股票代碼         日期  營業毛利率_A
# 0    1471 2023-06-01    10.80
# 1    1582 2023-06-01    16.98
# 2    2059 2023-06-01    58.29
# 3    2301 2023-06-01    18.79
# 4    2302 2023-06-01    32.32
# ..    ...        ...      ...
# 398  8215 2023-06-01    17.19
# 399  8249 2023-06-01    18.47
# 400  8261 2023-06-01    26.34
# 401  8271 2023-06-01    22.36
# 402  9912 2023-06-01    39.30
#
# [403 rows x 3 columns]

# %%
# 計算出產業平均營業毛利率
industry_GM_ave = GM_1Y_data["營業毛利率_A"].mean()

# 加入 '產業平均毛利率' 欄位
GM_1Y_data['產業平均毛利率'] = industry_GM_ave

GM_1Y_data
# Out:
#      股票代碼         日期  營業毛利率_A    產業平均毛利率
# 0    1471 2023-06-01    10.80  21.011166
# 1    1582 2023-06-01    16.98  21.011166
# 2    2059 2023-06-01    58.29  21.011166
# 3    2301 2023-06-01    18.79  21.011166
# 4    2302 2023-06-01    32.32  21.011166
# ..    ...        ...      ...        ...
# 398  8215 2023-06-01    17.19  21.011166
# 399  8249 2023-06-01    18.47  21.011166
# 400  8261 2023-06-01    26.34  21.011166
# 401  8271 2023-06-01    22.36  21.011166
# 402  9912 2023-06-01    39.30  21.011166
#
# [403 rows x 4 columns]

# %%
# 篩選符合選股條件1.的公司
set_1 = set(GM_1Y_data[GM_1Y_data['營業毛利率_A'] > GM_1Y_data['產業平均毛利率']]['股票代碼'])
set_1
len(set_1)
# Out:
# 179

# %% [markdown]
# ## 2. 最近月平均周轉率>10%

# %%
#挑選2023-05每個交易日的周轉率
data_last_2Y = data[data['日期'].isin(['2023-05-01', '2023-06-01'])].reset_index(drop = True) 
#計算個股的周轉率平均
turnover_2Y_ave = data_last_2Y.groupby('股票代碼')['周轉率'].mean()

turnover_2Y_ave = pd.DataFrame(turnover_2Y_ave).rename(columns = {'周轉率': '月平均周轉率'})

turnover_2Y_ave
# Out:
#        月平均周轉率
# 股票代碼
# 1471   0.3065
# 1582   0.0881
# 2059   0.6464
# 2301   0.5764
# 2302   4.5537
# ...       ...
# 8215   0.7665
# 8249   0.1858
# 8261   2.1656
# 8271  15.1669
# 9912   0.1648
#
# [403 rows x 1 columns]

# %%
# 篩選符合選股條件的公司
set_2 = set(turnover_2Y_ave[turnover_2Y_ave['月平均周轉率'] > 10].index)  # 篩選符合選股條件的公司
set_2
len(set_2)
# Out:
# 10

# %%
tickers = list(set_1 & set_2)
tickers
# Out:
# ['8271', '6235', '5258', '3025', '2482', '2457']

# %% [markdown]
# # 回測股票池買賣一年的績效

# %% [markdown]
# #### 導入股價資料(要改ticker)

# %%
start = '2023-06-01'
end = '2023-12-31'

os.environ['mdate'] = start + ' ' + end
os.environ['ticker'] = '8271'

# !zipline ingest -b tquant 
# 填入：將價量資料導入的程式碼
# Out:
# Merging daily equity files:
# Currently used TEJ API key call quota 732/1000 (73.2%)
# Currently used TEJ API key data quota 4773623/10000000 (47.74%)
# [2024-06-13 07:34:33.065934] INFO: zipline.data.bundles.core: Ingesting tquant.
# [2024-06-13 07:34:36.062546] INFO: zipline.data.bundles.core: Ingest tquant successfully.

# %% [markdown]
# # 建立 initialize 函式
# ##### commission手續費模型: PerDollar按照交易金額抽成計算  (抽成0.285%)
# ##### slippage滑價模型: VolumeShareSlippage根據該筆交易佔總交易量百分比來計算滑價，並可設定成交量限制 (交易限制2.5%)

# %%
from zipline.api import *
from zipline.finance import commission, slippage

def initialize(context):
    context.sym = symbol(os.environ['ticker'])
    context.i = 0
    context.invested = False
    context.set_commission(commission.PerDollar(cost=0.00285))
    context.set_slippage(slippage.VolumeShareSlippage(volume_limit=0.025, price_impact=0.1))

# %% [markdown]
# # 建立 handle_data 函式
#
# #### ->MACD參數
# ###### 短期指數移動平均線:12日
# ###### 長期指數移動平均線:26日
# ###### DIF:9日指數移動平均線
#
# #### ->RSI參數
# ###### 取14天內的平均漲幅跌幅
#
# #### ->設定交易策略
# ###### (1)MACD線上漲並穿過信號線 且 RSI >50 >>買進
# ###### (2)MACD線下跌並穿過信號線 且 RSI <50 >>賣出

# %%
def handle_data(context, data):
    trailing_window = data.history(context.sym, 'price', 35, '1d')#35 = 26 + 9
    if trailing_window.isnull().values.any():
        return

    short_ema = talib.EMA(trailing_window.values, timeperiod = 12)
    long_ema = talib.EMA(trailing_window.values, timeperiod = 26)
    dif = short_ema - long_ema
    MACD = talib.EMA(dif, timeperiod = 9)
    bar = dif - MACD
    rsi14 = talib.RSI(trailing_window.values, timeperiod=14)
    buy = False
    sell = False

    # Trading logic
    #condition1
    if (dif[-2] < MACD[-2]) and (dif[-1] > MACD[-1]) and (bar[-2] < 0) and (bar[-1] > 0) and (rsi14[-1] > 50):
        order_target(context.sym, 1000)
        context.invested = True
        buy = True
    
    #condition2
    elif (dif[-2] > MACD[-2]) and (dif[-1] < MACD[-1]) and (bar[-2] > 0) and (bar[-1] < 0) and (rsi14[-1] < 50) and context.invested:
        order_target(context.sym, 0)
        context.invested = False
        sell = True
        
    # Save values for later inspection
    record(stock_name = data.current(symbol(os.environ['ticker']), 'close'),
           dif = dif[-1],
           MACD = MACD[-1],
           bar = bar[-1],
           rsi14=rsi14[-1],
           buy = buy,
           sell = sell)

# %% [markdown]
# # 建立 analyze 函式

# %%
def analyze(context=None, results=None):
    import matplotlib.pyplot as plt
    import logbook
    logbook.StderrHandler().push_application()
    log = logbook.Logger('Algorithm')


    capital_base = 1e6
    #畫portfolio_value
    fig = plt.figure()
    ax1 = fig.add_subplot(311)
    #results['benchmark_cum'] = results.benchmark_return.add(1).cumprod() * capital_base
    #results[['portfolio_value', 'benchmark_cum']].plot(ax = ax1, label = 'Portfolio Value($)')
    results.portfolio_value.plot(ax=ax1,title='portfolio values')
    ax1.set_ylabel('Portfolio value (TWD)')

    #畫MACD(曲線和BAR)
    ax2 = fig.add_subplot(312, sharex = ax1,title='MACD')
    ax2.set_ylabel('MACD')

    if 'dif' in results and 'MACD' in results:
        results[['dif', 'MACD']].plot(ax=ax2)
        ax2.plot(
            results.index[results["buy"] == True],
            results.loc[results["buy"] == True, 'MACD'],
            '^',
            markersize=10,
            color='m',
        )
        ax2.plot(
            results.index[results["sell"] == True],
            results.loc[results["sell"] == True, 'MACD'],
            'v',
            markersize=10,
            color='k',
        )

        ax3 = ax2.twinx()
        colors = ["red" if i > 0 else "green" for i in results['bar']]
        ax3.bar(results.index, results['bar'], color=colors, alpha=0.5, width=0.4, label='MACD Bar')
        
        lines, labels = ax2.get_legend_handles_labels()
        bars, bar_labels = ax3.get_legend_handles_labels()
        ax2.legend(lines + bars, labels + bar_labels, loc='upper right')
        
        plt.gcf().set_size_inches(18, 8)

    else:
        msg = ' dif and MACD data not captured using record().'
        ax2.annotate(msg, xy=(0.1, 0.5))
        log.info(msg)

    #畫RSI
    ax4 = fig.add_subplot(313, sharex = ax1,title='RSI')
    if 'rsi14' in results:
        ax4.plot(results.index, results['rsi14'], label='RSI14', color='blue')
        ax4.set_ylabel('RSI14')
        ax4.legend()


    plt.show()

# %% [markdown]
# # 執行交易策略

# %%
from zipline import run_algorithm

start_date = pd.Timestamp('2023-06-01',tz='utc')
end_date = pd.Timestamp('2023-12-31',tz='utc')

results = run_algorithm(start= start_date,  
                       end=end_date,
                       initialize=initialize,                       
                       capital_base=1e6,
                       analyze=analyze,
                       handle_data=handle_data,
                       data_frequency='daily',
                       bundle='tquant'
                       )
# Out:
# [2024-06-13 07:35:08.148126] INFO: zipline.finance.metrics.tracker: Simulated 146 trading days
# first open: 2023-06-01 01:01:00+00:00
# last close: 2023-12-29 05:30:00+00:00

# %%
results.returns.cumsum().plot()  
# 繪製累積回報圖
# Out:
# <Axes: >

# %% [markdown]
# # 投資組合 sharpe ration

# %%
start = '2023-06-01'
end = '2023-12-31'


#print(tickers)
os.environ['mdate'] = start + ' ' + end
os.environ['ticker'] = ' '.join(tickers) + ' ' + 'IR0001'


# !zipline ingest -b tquant
# Out:
# ['8271', '6235', '5258', '3025', '2482', '2457']
# Merging daily equity files:
# Currently used TEJ API key call quota 757/1000 (75.7%)
# Currently used TEJ API key data quota 4784385/10000000 (47.84%)
# [2024-06-13 07:45:25.028137] INFO: zipline.data.bundles.core: Ingesting tquant.
# [2024-06-13 07:45:28.182060] INFO: zipline.data.bundles.core: Ingest tquant successfully.

# %%
from zipline.api import *
from zipline.finance import commission, slippage

def initialize(context):
    context.day = 0
    context.tickers = tickers
    set_slippage(slippage.VolumeShareSlippage(volume_limit = 0.025, price_impact = 0.1)) # 填入：本範例使用的滑價模型
    set_commission(commission.Custom_TW_Commission(min_trade_cost = 20, discount = 1.0, tax = 0.003))  # 填入：本範例使用的手續費模型
    set_benchmark(symbol('IR0001'))

# %%
def handle_data(context, data):
    
    trailing_window = data.history(context.sym, 'price', 35, '1d')#35 = 26 + 9
    if trailing_window.isnull().values.any():
        return

    short_ema = talib.EMA(trailing_window.values, timeperiod = 12)
    long_ema = talib.EMA(trailing_window.values, timeperiod = 26)
    dif = short_ema - long_ema
    MACD = talib.EMA(dif, timeperiod = 9)
    bar = dif - MACD
    rsi14 = talib.RSI(trailing_window.values, timeperiod=14)
    buy = False
    sell = False

    # Trading logic
    #condition1
    if (dif[-2] < MACD[-2]) and (dif[-1] > MACD[-1]) and (bar[-2] < 0) and (bar[-1] > 0) and (rsi14[-1] > 50):
        order_target(context.sym, 1000)
        context.invested = True
        buy = True
    
    #condition2
    elif (dif[-2] > MACD[-2]) and (dif[-1] < MACD[-1]) and (bar[-2] > 0) and (bar[-1] < 0) and (rsi14[-1] < 50) and context.invested:
        order_target(context.sym, 0)
        context.invested = False
        sell = True
        
    # Save values for later inspection
    record(stock_name = data.current(symbol(tickers), 'close'),
           dif = dif[-1],
           MACD = MACD[-1],
           bar = bar[-1],
           rsi14=rsi14[-1],
           buy = buy,
           sell = sell)

# %%
import matplotlib.pyplot as plt
capital_base = 1e6
def analyze(context=None, results=None):

    #畫portfolio_value
    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    results['benchmark_cum'] = results.benchmark_return.add(1).cumprod() * capital_base
    results[['portfolio_value', 'benchmark_cum']].plot(ax = ax1, label = 'Portfolio Value($)')
    #results.portfolio_value.plot(ax=ax1,title='portfolio values')
    ax1.set_ylabel('Portfolio value (TWD)')
    plt.legend(loc = 'upper left')
    plt.gcf().set_size_inches(18, 8)
    plt.grid()
    plt.show()

# %%
from zipline import run_algorithm
from zipline.utils.run_algo import get_transaction_detail

start_date = pd.Timestamp('2023-06-01',tz='utc')
end_date = pd.Timestamp('2023-12-31',tz='utc')

results = run_algorithm(start= start_date,  
                       end=end_date,
                       initialize=initialize,                       
                       capital_base=capital_base,
                       analyze=analyze,
                       handle_data=handle_data,
                       data_frequency='daily',
                       )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[127], line 7
#       4 start_date = pd.Timestamp('2023-06-01',tz='utc')
#       5 end_date = pd.Timestamp('2023-12-31',tz='utc')
# ----> 7 results = run_algorithm(start= start_date,
#       8                        end=end_date,
#       9                        initialize=initialize,
#      10                        capital_base=capital_base,
#      11                        analyze=analyze,
#      12                        handle_data=handle_data,
#      13                        data_frequency='daily',
#      14                        )
#
# File ~\anaconda3\envs\zipline-tej\Lib\site-packages\zipline\utils\run_algo.py:483, in run_algorithm(start, end, initialize, capital_base, handle_data, before_trading_start, analyze, data_frequency, bundle, bundle_timestamp, trading_calendar, metrics_set, benchmark_returns, treasury_returns, default_extension, extensions, strict_extensions, environ, custom_loader, blotter)
#     480 benchmark_spec = BenchmarkSpec.from_returns(benchmark_returns)
#     481 treasury_spec = TreasurySpec.from_returns(treasury_returns)    #20230210(by MRC) for treasury return column in perf
# --> 483 return _run(
#     484     handle_data=handle_data,
#     485     initialize=initialize,
#     486     before_trading_start=before_trading_start,
#     487     analyze=analyze,
#     488     algofile=None,
#     489     algotext=None,
#     490     defines=(),
#     491     data_frequency=data_frequency,
#     492     capital_base=capital_base,
#     493     bundle=bundle,
#     494     bundle_timestamp=bundle_timestamp,
#     495     start=start,
#     496     end=end,
#     497     output=os.devnull,
#     498     trading_calendar=trading_calendar,
#     499     print_algo=False,
#     500     metrics_set=metrics_set,
#     501     local_namespace=False,
#     502     environ=environ,
#     503     blotter=blotter,
#     504     custom_loader=custom_loader,
#     505     benchmark_spec=benchmark_spec,
#     506     treasury_spec=treasury_spec           #20230209 (by MRC) for treasury return column in perf
#     507 )
#
# File ~\anaconda3\envs\zipline-tej\Lib\site-packages\zipline\utils\run_algo.py:291, in _run(handle_data, initialize, before_trading_start, analyze, algofile, algotext, defines, data_frequency, capital_base, bundle, bundle_timestamp, start, end, output, trading_calendar, print_algo, metrics_set, local_namespace, environ, blotter, custom_loader, benchmark_spec, treasury_spec)
#     259         raise _RunAlgoError(str(e))
#     261 try:
#     262     perf = TradingAlgorithm(
#     263         namespace=namespace,
#     264         data_portal=data,
#     265         get_pipeline_loader=choose_loader,
#     266         trading_calendar=trading_calendar,
#     267         sim_params=SimulationParameters(
#     268             start_session=start,
#     269             end_session=end,
#     270             trading_calendar=trading_calendar,
#     271             capital_base=capital_base,
#     272             data_frequency=data_frequency,
#     273         ),
#     274         metrics_set=metrics_set,
#     275         blotter=blotter,
#     276         benchmark_returns=benchmark_returns,
#     277         benchmark_sid=benchmark_sid,
#     278         treasury_returns=treasury_returns,    #20230209  (by MRC) for treasury return column in perf
#     279         treasury_sid=treasury_sid,            #20230209  (by MRC) for treasury return column in perf
#     280         **{
#     281             "initialize": initialize,
#     282             "handle_data": handle_data,
#     283             "before_trading_start": before_trading_start,
#     284             "analyze": analyze,
#     285         }
#     286         if algotext is None
#     287         else {
#     288             "algo_filename": getattr(algofile, "name", "<algorithm>"),
#     289             "script": algotext,
#     290         },
# --> 291     ).run()
#     294 except NoBenchmark:
#     295     raise _RunAlgoError(
#     296         (
#     297             "No ``benchmark_spec`` was provided, and"
#    (...)
#     305         ),
#     306     )
#
# File ~\anaconda3\envs\zipline-tej\Lib\site-packages\zipline\algorithm.py:689, in TradingAlgorithm.run(self, data_portal)
#     687 try:
#     688     perfs = []
# --> 689     for perf in self.get_generator():
#     690         perfs.append(perf)
#     692     # convert perf dict to pandas dataframe
#
# File ~\anaconda3\envs\zipline-tej\Lib\site-packages\zipline\gens\tradesimulation.py:230, in AlgorithmSimulator.transform(self)
#     228 for dt, action in self.clock:
#     229     if action == BAR:
# --> 230         for capital_change_packet in every_bar(dt):
#     231             yield capital_change_packet
#     232     elif action == SESSION_START:
#
# File ~\anaconda3\envs\zipline-tej\Lib\site-packages\zipline\gens\tradesimulation.py:144, in AlgorithmSimulator.transform.<locals>.every_bar(dt_to_use, current_data, handle_data)
#     141 for commission in new_commissions:
#     142     metrics_tracker.process_commission(commission)
# --> 144 handle_data(algo, current_data, dt_to_use)
#     146 # grab any new orders from the blotter, then clear the list.
#     147 # this includes cancelled orders.
#     148 new_orders = blotter.new_orders
#
# File ~\anaconda3\envs\zipline-tej\Lib\site-packages\zipline\utils\events.py:206, in EventManager.handle_data(self, context, data, dt)
#     204 with self._create_context(data):
#     205     for event in self._events:
# --> 206         event.handle_data(
#     207             context,
#     208             data,
#     209             dt,
#     210         )
#
# File ~\anaconda3\envs\zipline-tej\Lib\site-packages\zipline\utils\events.py:229, in Event.handle_data(self, context, data, dt)
#     225 """
#     226 Calls the callable only when the rule is triggered.
#     227 """
#     228 if self.rule.should_trigger(dt):
# --> 229     self.callback(context, data)
#
# File ~\anaconda3\envs\zipline-tej\Lib\site-packages\zipline\algorithm.py:482, in TradingAlgorithm.handle_data(self, data)
#     480 def handle_data(self, data):
#     481     if self._handle_data:
# --> 482         self._handle_data(self, data)
#
# Cell In[123], line 3, in handle_data(context, data)
#       1 def handle_data(context, data):
# ----> 3     trailing_window = data.history(context.sym, 'price', 35, '1d')#35 = 26 + 9
#       4     if trailing_window.isnull().values.any():
#       5         return
#
# AttributeError: 'TradingAlgorithm' object has no attribute 'sym'

# %%
from pyfolio.utils import extract_rets_pos_txn_from_zipline
import pyfolio

returns, positions, transactions = extract_rets_pos_txn_from_zipline(results)  # 從 results 資料表中取出 returns, positions & transactions
benchmark_rets = results.benchmark_return  # 取出 benchmark 的報酬率

# 繪製夏普比率圖

from pyfolio.plotting import plot_rolling_sharpe

plot_rolling_sharpe(returns,
                    factor_returns=benchmark_rets)
